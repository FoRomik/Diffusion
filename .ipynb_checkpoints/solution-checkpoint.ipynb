# %% [markdown]
# # Techniques of High Performance Computing: First Assignment
# ### Jan Zmazek, Scientific Computing
# This Python package imports a triangular grid from a legacy vtk file, or creates a square grid with $m\cdot n$ nodes, and solves a diffusion equation
# $$\begin{cases}
# -\nabla\cdot\sigma(r)\nabla u(r)=f(r) & \text{in } \Omega\\
# u(r)=0 &\text{on }\partial\Omega.
# \end{cases}$$
# using a finite element method. It consists of three classes of methods: grid (to read a vtk file), squareGrid (to create a square grid) and fem (finite element method).
#
#
# ## Examples

# %%
from main import solve

def f(x,y):
    return 1

def sigma(x,y):
    return 1

solve("example.vtk", sigma, f)

# %% [markdown]
# For bonus points, I have also implemented a class

# %%
from main import solve_square
solve_square(10, 10, sigma, f)

# %%
from source.squareGrid import SquareGrid
from source.fem import Fem
grid = SquareGrid(3,3)
vertices_matrix = grid.get_vertices_matrix()
connectivity_matrix = grid.get_connectivity_matrix()
fem = Fem(vertices_matrix, connectivity_matrix)

# %%
fem.local_assembly([0,1,4], lambda x, y: 1, lambda x, y: 1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-e4017ae7564d> in <module>()
# ----> 1 fem.local_assembly([0,1,4], 1, 1)
#
# /Users/janzmazek/Desktop/HPC1/FEM/source/fem.py in local_assembly(self, element, sigma, function)
#      44         determinant = abs(np.linalg.det(mapping_matrix))
#      45         shape = Triangle(inverse_transpose, determinant)
# ---> 46         self.local_stiffness = shape.get_local_stiffness(sigma)
#      47         self.local_load = shape.get_local_load(function)
#      48
#
# /Users/janzmazek/Desktop/HPC1/FEM/source/triangle.py in get_local_stiffness(self, sigma)
#      29                         nabla_psi_2))*self.determinant
#      30                 integral = integral_constant*integrate.dblquad(
# ---> 31                     sigma, 0, 1, lambda x: 0, lambda x: 1-x)[0]
#      32                 local_stiffness[i][j] = integral
#      33                 local_stiffness[j][i] = integral
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     495     def temp_ranges(*args):
#     496         return [gfun(args[0]), hfun(args[0])]
# --> 497     return nquad(func, [temp_ranges, [a, b]], args=args)
#     498
#     499
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in nquad(func, ranges, args, opts, full_output)
#     705     else:
#     706         opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> 707     return _NQuad(func, ranges, opts, full_output).integrate(*args)
#     708
#     709
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     760             f = partial(self.integrate, depth=depth+1)
#     761         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 762                       **opt)
#     763         value = quad_r[0]
#     764         abserr = quad_r[1]
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     313     if (weight is None):
#     314         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 315                        points)
#     316     else:
#     317         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     378     if points is None:
#     379         if infbounds == 0:
# --> 380             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     381         else:
#     382             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     760             f = partial(self.integrate, depth=depth+1)
#     761         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 762                       **opt)
#     763         value = quad_r[0]
#     764         abserr = quad_r[1]
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     313     if (weight is None):
#     314         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 315                        points)
#     316     else:
#     317         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /Users/janzmazek/anaconda/lib/python3.5/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     378     if points is None:
#     379         if infbounds == 0:
# --> 380             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     381         else:
#     382             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# error: quad: first argument is not callable
